# %%
import math
import collections
import pickle
import random
import scipy
import json

from matplotlib import pyplot as plt

import GPy
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
Output = pd.read_excel('Titer_OD.xlsx', 'Repeat')
N_unique = len(Output['Production Condition'].unique())

# %%
initN = Output.shape[0]

Titer = []
Prod_OD = []
OG_OD = []
Spec_prod = []
Conditions = []
names_all = Output['Production Condition'].unique()

for name in names_all:
    fac = int(Output.shape[0]/N_unique)
    Conditions = Conditions + [name]*fac
    temp1 = Output['Titer'].loc[Output ['Production Condition'] == name]
    temp2 = Output['OD_Prod'].loc[Output ['Production Condition'] == name]
    temp3 = Output['OD_OG'].loc[Output ['Production Condition'] == name]
    
    Titer = Titer + temp1.tolist()
    Prod_OD = Prod_OD + temp2.tolist()
    OG_OD = OG_OD + temp3.tolist()
    Spec_prod = Spec_prod + (temp1/temp2).tolist()

Data = {'Condition': Conditions, 'Titer': Titer, 
         'Specific Productivity': Spec_prod, 'Prod_OD': Prod_OD, 'OG_OD': OG_OD}

Round3_summary = pd.DataFrame(Data)

# %%
# pd.DataFrame(Data).max()
plt.scatter(Titer, Spec_prod)

# %%
Round3_summary.to_csv('Round0_Result_Summary_detailed.csv')

# %%
Round3_summary
# Out:
#              Condition       Titer  Specific Productivity    Prod_OD     OG_OD
# 0                 Exp0   23.041688               2.390217   9.640000  2.653750
# 1                 Exp0   20.789311               2.367129   8.782500  2.362500
# 2                 Exp1   42.397614               4.665487   9.087500  5.025000
# 3                 Exp1   42.168493               4.839999   8.712500  5.391250
# 4                 Exp2   11.359309               1.345690   8.441250  6.305000
# 5                 Exp2   11.334244               1.469118   7.715000  6.125000
# 6                 Exp3   52.374527               4.672126  11.210000  2.795000
# 7                 Exp3   53.451449               4.208776  12.700000  3.258750
# 8                 Exp4   42.717150               4.182830  10.212500  3.645000
# 9                 Exp4   43.530096               4.238568  10.270000  4.078750
# 10                Exp5   34.080229               3.665033   9.298750  4.578750
# 11                Exp5   33.027461               3.274909  10.085000  5.610000
# 12                Exp6   67.913947               7.480539   9.078750  2.805000
# 13                Exp6   69.608928               7.494905   9.287500  3.487500
# 14                Exp7   11.842123               1.478879   8.007500  3.357500
# 15                Exp7   12.300821               1.585668   7.757500  3.106250
# 16                Exp8    4.996354               0.229651  21.756250  3.417500
# 17                Exp8    4.898763               0.223026  21.965000  3.436250
# 18                Exp9   12.538350               1.072915  11.686250  6.025000
# 19                Exp9   12.530559               1.002645  12.497500  6.233750
# 20               Exp10   31.157435               3.411242   9.133750  5.308750
# 21               Exp10   32.212839               3.507114   9.185000  5.707500
# 22               Exp11    5.413186               0.441758  12.253750  5.383750
# 23               Exp11    6.583823               0.561760  11.720000  5.070000
# 24               Exp12   10.772134               1.623226   6.636250  2.288750
# 25               Exp12   10.279705               1.650364   6.228750  2.273750
# 26               Exp13   13.606388               1.876743   7.250000  2.335000
# 27               Exp13   14.372526               1.982076   7.251250  2.515000
# 28               Exp14   54.981698               4.814509  11.420000  4.553750
# 29               Exp14   52.244248               4.736559  11.030000  4.113333
# 30               Exp15  103.212082               8.936111  11.550000  4.826250
# 31               Exp15  124.089972               9.126779  13.596250  6.386250
# 32               Exp16   31.751296               3.141749  10.106250  6.160000
# 33               Exp16   32.027025               3.113955  10.285000  5.427500
# 34               Exp17   16.256326               1.212819  13.403750  4.165000
# 35               Exp17   18.395363               1.210354  15.198334  3.725000
# 36               Exp18   36.801489               3.521252  10.451250  3.901250
# 37               Exp18   37.281559               3.718395  10.026250  3.798750
# 38               Exp19    7.124413               0.397901  17.905000  2.527500
# 39               Exp19    7.630452               0.373287  20.441250  2.642500
# 40               Exp20    3.046981               0.158511  19.222500  3.343750
# 41               Exp20    3.030882               0.172185  17.602500  3.556250
# 42               Exp21    9.671267               1.213840   7.967500  3.413750
# 43               Exp21    9.895562               1.257977   7.866250  3.866250
# 44               Exp22   23.485577               2.516874   9.331250  4.658750
# 45               Exp22   21.446963               2.353899   9.111250  4.283750
# 46  BMGY, BMMY + Cells   51.606035               5.704688   9.046250  4.137500
# 47  BMGY, BMMY + Cells   52.090126               5.726287   9.096667  4.073333
