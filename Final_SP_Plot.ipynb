# %%
from Plot_Functions import CollectData

import numpy as np
import pandas as pd
import json



from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GroupKFold

import scipy
from scipy.stats import norm
from scipy.optimize import minimize
import matplotlib.pyplot as plt
#import matplotlib
from scipy.optimize import NonlinearConstraint


from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,
                                              ExpSineSquared, DotProduct,
                                              ConstantKernel)
from sklearn.model_selection import train_test_split


import seaborn as sns
import GPy
import GPyOpt
from numpy.random import seed

# %%
params = {'axes.titlesize': 20, 'xtick.labelsize': 20, 'ytick.labelsize': 20, 'axes.labelsize': 20}
hfont = {'fontname':'Arial'} 
plt.rcParams.update(params)
plt.rcParams["figure.figsize"] = (12, 4)
f, ax = plt.subplots(1, 3)

c_name = [ 'forestgreen','powderblue', 'tan']*3 #'thistle',  ,'forestgreen'
label_names = ['Benchmark 1', 'Benchmark 2', 'Optimal']

x = [[0, 0, 0], [1, 1, 1], [2, 2, 2]]

SP = {}
SP[0]=[[5.772113, 5.28038765, 5.10287844],
[5.15892265, 6.44885145, 5.52202947],
[10.0054664, 10.6754378, 11.1014041]]

SP[1] = [[3.5,4.2,5.1],
[2.65697094,3.36191061,3.5047681],
[6.08512164,6.4253718,6.17401468]]


SP[2] = [[4.1,5,6],
[1.2,2,2.9],
[6.77,6.8,6.6]]


for i in range(3):
    if i == 0:
        barlist = ax[i].bar([0 , 1, 2], np.mean(SP[i], axis =1), width = 0.5,facecolor= c_name[i], alpha = 0.5)
        ax[i].set_ylabel('Specific Productivity', **hfont)
    else:
        barlist = ax[i].bar([0 , 1, 2], np.mean(SP[i], axis =1), width = 0.5,facecolor= c_name[i], alpha = 1)
        
    ax[i].scatter(x, SP[i],100, 'k')
    
    ax[i].set_xticks([0, 1, 2], **hfont)
    ax[i].set_yticks(np.arange(0, 15, 3),**hfont)
    ax[i].set_yticklabels(np.arange(0, 14, 3), **hfont)
    ax[i].set_xticklabels(label_names, rotation = 45, **hfont)
    
            

plt.savefig("./Plots/SpecificProductivity_Molecules", dpi = 300, bbox_inches = 'tight')
